# %%
import pandas as pd
import os
from matplotlib import pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib as mpl
from matplotlib.pyplot import cm

# %%
import sys
print(sys.path) 
sys.path.append("/cellar/users/mpagadal/Programs/anaconda3/lib/python3.7/site-packages")
sys.path.insert(1, '/cellar/users/mpagadal/Data/gcta/scripts')
# Out:
# ['/data/cellardata/users/mpagadal/projects/germline-immune/cell-type-specificity/notebooks', '/nrnb/opt/anaconda3.7/lib/python37.zip', '/nrnb/opt/anaconda3.7/lib/python3.7', '/nrnb/opt/anaconda3.7/lib/python3.7/lib-dynload', '', '/cellar/users/mpagadal/.local/lib/python3.7/site-packages', '/nrnb/opt/anaconda3.7/lib/python3.7/site-packages', '/nrnb/opt/anaconda3.7/lib/python3.7/site-packages/IPython/extensions', '/cellar/users/mpagadal/.ipython']

# %%
import networkx as nx
from ndex2.nice_cx_network import NiceCXNetwork 
import ndex2.client as nc
import ndex2

# %%
import matplotlib
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['ps.fonttype'] = 42

# %%
import matplotlib.pyplot as plt
from matplotlib_venn import venn2
from matplotlib_venn import venn3

# %%
import statsmodels.stats.multitest as multi
from adjustText import adjust_text

# %%
import numpy as np
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
import json

# %% [markdown]
# ## Get GTEx summary statistics for immune microenvironment SNPs from all tissue types

# %% [markdown]
# ### Run compile_gtex.sh

# %% [markdown]
# script will extract variants of interact from GTEx summary statistics

# %%
with open('/cellar/users/mpagadal/Data/resources/tcga/ensembl_map.json', 'r') as f:
    ensembl_dict = json.load(f)

# %%
ensembl_dict={k.split(".")[0]:v for k,v in ensembl_dict.items()}

# %%
def compile_gtex(directory,file_name,mapping):
    gtex_files=[x for x in os.listdir(directory)]
    total_gtex=pd.DataFrame()

    for x in gtex_files:
        cis=pd.read_csv(directory+x)
        cis["file"]=x.split(file_name)[0]
        total_gtex=total_gtex.append(cis)
    
    #format variant2 and gene
    total_gtex["variant2"]=total_gtex["variant_b37"].str.split("_").str[0]+":"+total_gtex["variant_b37"].str.split("_").str[1]+":"+total_gtex["variant_b37"].str.split("_").str[3]+":"+total_gtex["variant_b37"].str.split("_").str[2]
    #get gene ids for mapping
    total_gtex["gene_id"]=total_gtex["phenotype_id"].str.split(".").str[0]
    
    total_gtex["ref"]=total_gtex["variant_id"].str.split("_").str[2]
    total_gtex["alt"]=total_gtex["variant_id"].str.split("_").str[3]
    
    total_gtex_melt=pd.melt(total_gtex, id_vars=(["gene_id","slope","slope_se","ref","alt","file","pval_nominal","maf","tss_distance","variant_b37"]),value_vars=(["variant","variant2"]))
    
    total_gtex_melt["gene_name"]=total_gtex_melt["gene_id"].map(mapping)
    
    total_gtex_melt["assoc"]=total_gtex_melt["value"]+"_"+total_gtex_melt["gene_name"]
    
    return(total_gtex_melt)

# %%
gtex=compile_gtex("/cellar/users/mpagadal/Data/gtex/extracted_snps/",".snps.csv",ensembl_dict)

# %%
print(gtex.shape)
gtex.head()
# Out:
# (1549580, 14)
#            gene_id     slope  slope_se ref alt           file  pval_nominal  \
# 0  ENSG00000237094  0.471558  0.461462   G   A  Kidney_Cortex      0.312301
# 1  ENSG00000225972  0.571838  0.349512   G   A  Kidney_Cortex      0.108794
# 2  ENSG00000225630  0.803202  0.276528   G   A  Kidney_Cortex      0.005682
# 3  ENSG00000237973  0.565607  0.339045   G   A  Kidney_Cortex      0.102213
# 4  ENSG00000229344  0.493088  0.346081   G   A  Kidney_Cortex      0.161121
#
#         maf  tss_distance        variant_b37 variable          value  \
# 0  0.053846        984755  1_1421752_G_A_b37  variant  1:1421752:G:A
# 1  0.053846        857310  1_1421752_G_A_b37  variant  1:1421752:G:A
# 2  0.053846        856732  1_1421752_G_A_b37  variant  1:1421752:G:A
# 3  0.053846        855298  1_1421752_G_A_b37  variant  1:1421752:G:A
# 4  0.053846        853615  1_1421752_G_A_b37  variant  1:1421752:G:A
#
#        gene_name                        assoc
# 0  RP4-669L17.10  1:1421752:G:A_RP4-669L17.10
# 1       MTND1P23       1:1421752:G:A_MTND1P23
# 2       MTND2P28       1:1421752:G:A_MTND2P28
# 3   RP5-857K21.6   1:1421752:G:A_RP5-857K21.6
# 4   RP5-857K21.7   1:1421752:G:A_RP5-857K21.7

# %% [markdown]
# ## Get TCGA summary statistics for immune microenvironment SNPs for all cancer types

# %%
snps=pd.read_csv("/cellar/users/mpagadal/Data/projects/germline-immune/snp-tables/immune-microenvironment-nonhla.tsv",delimiter="\t")
snps["assoc"]=snps["snps"]+"_"+snps["file"]

# %%
#map to minor allele frequency
mp_maf=dict(zip(snps["snps"],snps["maf"]))

# %%
#snps found in gtex
gtex=gtex[gtex["value"].isin(snps["snps"].tolist())]

# %%
gtex_snps=len(gtex["value"].unique().tolist())
all_snps=len(snps["snps"].unique().tolist())
print(gtex_snps)
print(all_snps)
# Out:
# 446
# 475

# %%
"The following snps were not found {}".format(" ".join(snps[~snps["snps"].isin(gtex["value"].tolist())]["snps"].tolist()))
# Out:
# 'The following snps were not found 5:69733811:T:C 19:54856354:G:A 19:54861175:G:A 19:54861462:G:T 19:54793198:G:C 19:54783035:T:G 19:54749474:T:G 5:96206416:G:T 5:96225449:G:A 5:96357030:G:T 5:96326397:T:G 6:32605437:G:C 6:32624038:C:T 5:80203678:A:C 15:45363341:G:A 19:55025471:C:A 11:65504069:A:C 1:89477830:T:C 3:48516525:A:T 5:96039895:G:T 5:96152809:A:G 10:97359625:T:C 5:79927651:G:A 5:79951030:G:A 5:96201579:A:C 5:96324943:G:T 12:8214856:A:C 7:153338633:G:A 2:212571330:A:C'

# %% [markdown]
# ### See how many snps were found

# %%
f=plt.figure(figsize=(3,3))
labels = 'gtex', 'not found'
sizes = [gtex_snps/all_snps,(1-(gtex_snps/all_snps))]
colors = ['green', 'darkgray']
explode = (0.1, 0.0)  # explode 1st slice
mpl.rcParams['font.size'] = 10
# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=False, startangle=140)
plt.axis('equal')
f.savefig("../plots/gtex.snps.found.pdf")

# %% [markdown]
# ### See how many gene ids were not mapped

# %%
#how many gene ids were not mapped
print("{} gene ids were not mapped".format(len(gtex[gtex["gene_name"].isnull()]["gene_id"].unique().tolist())))
#remove rows for which gene name was not mapped
gtex=gtex[~(gtex["gene_name"].isnull())]
# Out:
# 34 gene ids were not mapped

# %%
#rename columns
gtex.columns=["gene_id","gtex slope","gtex slope_se","ref","alt","gtex cell_type","pval","gtex maf","tss_distance","variant id","variable","snps","gtex file","assoc"]

# %%
del gtex["assoc"]

# %% [markdown]
# ### make dataframe with gtex and tcga information

# %%
snps_gtex=pd.merge(gtex,snps,on=["snps"],how="left")

# %%
#switch gtex beta if alt allele do not align
snps_gtex["gtex slope"]=np.where(snps_gtex["alt"] != snps_gtex["ALT"], (snps_gtex["gtex slope"]*-1),snps_gtex["gtex slope"])

# %%
#export results
snps_gtex.to_csv("../data/gtex_variant_information.tsv",sep="\t")

# %% [markdown]
# ### make cis and trans dataframes

# %%
#make cis and trans dataframes
snps_gtex_cis=snps_gtex[snps_gtex["gtex file"]==snps_gtex["file"]]
snps_gtex_trans=snps_gtex[snps_gtex["gtex file"]!=snps_gtex["file"]]

# %%
cis_trans=len(snps_gtex_trans[snps_gtex_trans["assoc"].isin(snps_gtex_cis["assoc"].tolist())]["assoc"].unique())
trans=len(snps_gtex_trans[~snps_gtex_trans["assoc"].isin(snps_gtex_cis["assoc"].tolist())]["assoc"].unique())
cis=len(snps_gtex_cis[~snps_gtex_cis["assoc"].isin(snps_gtex_trans["assoc"].tolist())]["assoc"].unique())
notfound=len(snps[~snps["assoc"].isin(snps_gtex["assoc"].tolist())])

# %%
f=plt.figure(figsize=(3,3))
labels = 'cis','trans','not found'
sizes = [cis_trans/len(snps),trans/len(snps), notfound/len(snps)]
colors = ['forestgreen', 'purple','silver']
explode = (0.1, 0.1,0)  # explode 1st slice
mpl.rcParams['font.size'] = 10
# Plot
plt.pie(sizes, explode=explode, labels=labels, colors=colors,
autopct='%1.1f%%', shadow=False, startangle=140)
plt.axis('equal')
f.savefig("../plots/gtex.cis.trans.pdf")

# %% [markdown]
# ## Get sample sizes for tissues

# %%
tissue_num=pd.read_csv("/cellar/users/mpagadal/Data/gtex/GTEx.tissue.sample.size.csv")

# %%
tissue_num["Tissue"]=tissue_num["Tissue"].str.replace("- ","")
tissue_num["Tissue"]=tissue_num["Tissue"].str.replace(" ","_")
tissue_num["Tissue"]=tissue_num["Tissue"].str.replace("(","")
tissue_num["Tissue"]=tissue_num["Tissue"].str.replace(")","")

# %%
mp_num=dict(zip(tissue_num["Tissue"],tissue_num["# RNASeq and Genotyped samples"]))

# %%
#map number of samples per cell type
snps_gtex_cis["number"]=snps_gtex_cis["gtex cell_type"].map(mp_num)
# Out:
# /nrnb/opt/anaconda3.7/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %% [markdown]
# ## Get mapping between gtex/tcga tissues

# %%
#get tissue mappings
tissue_mapping=pd.read_csv("../data/gtex.tcga.tissue.csv")
tissue_mapping["combo"]=tissue_mapping["gtex tissues"]+"."+tissue_mapping["TCGA"]

# %%
tissue_mapping["whole_blood combo"]="Whole_Blood"+"."+tissue_mapping["TCGA"]

# %%
tissue_mapping.head()
# Out:
#                      gtex tissues  TCGA                                combo  \
# 0  Small_Intestine_Terminal_Ileum  COAD  Small_Intestine_Terminal_Ileum.COAD
# 1                   Kidney_Cortex  KIRP                   Kidney_Cortex.KIRP
# 2                   Kidney_Cortex  KICH                   Kidney_Cortex.KICH
# 3                   Kidney_Cortex  KIRC                   Kidney_Cortex.KIRC
# 4                          Testis  TGCT                          Testis.TGCT
#
#   whole_blood combo
# 0  Whole_Blood.COAD
# 1  Whole_Blood.KIRP
# 2  Whole_Blood.KICH
# 3  Whole_Blood.KIRC
# 4  Whole_Blood.TGCT

# %% [markdown]
# ## PCA analysis of different cell types

# %%
#make dataframe for pca analysis
df_cell=snps_gtex_cis.pivot(index="gtex cell_type",columns="assoc",values="gtex slope")
df_cell=df_cell.fillna(0) #if missing, fill value with 0

# %%
df_cell=df_cell[df_cell.index.isin(tissue_mapping["gtex tissues"].tolist()+["Whole_Blood"])]

# %%
scaler=StandardScaler()
scaler.fit(df_cell)
X_scaled=scaler.transform(df_cell)

# %%
pca = PCA(n_components=10)

# %%
pca.fit(X_scaled)
# Out:
# PCA(copy=True, iterated_power='auto', n_components=10, random_state=None,
#     svd_solver='auto', tol=0.0, whiten=False)

# %%
mp_variance={}

for i,val in enumerate(pca.explained_variance_ratio_.tolist()):
    key="PC"+str(i+1)
    mp_variance[key]=val

# %%
X_pca=pca.transform(X_scaled)

# %%
df=pd.DataFrame(X_pca)
df.index=df_cell.index
df.columns=["PC"+str(x+1) for x in df.columns]

# %%
df["num"]=df.index.map(mp_num)

# %%
x="PC1"
y="PC2"

# %%
df=df.sort_values(by="PC1")

# %%
f=plt.figure(figsize=(10,10))

n=df.index.unique()
color=iter(cm.rainbow(np.linspace(0,1,len(n))))

for t, c in zip(n, color):
    plt.scatter(df[df.index==t][x].values[0], df[df.index==t][y].values[0], s=df[df.index==t]["num"].values[0], color=c)

for i, row in df.iterrows():
    plt.annotate(i, (row[x], row[y]))

plt.xlabel(x+"="+"{0:.2f}%".format(mp_variance[x]*100),fontsize=15)
plt.ylabel(y+"="+"{0:.2f}%".format(mp_variance[y]*100),fontsize=15)
f.savefig("../plots/gtex.pca.pdf")

# %% [markdown]
# ## Plot QQ plot

# %%
def ppoints(n, a):
    """ numpy analogue or `R`'s `ppoints` function
        see details at http://stat.ethz.ch/R-manual/R-patched/library/stats/html/ppoints.html 
        :param n: array type or number"""
    try:
        n = np.float(len(n))
    except TypeError:
        n = np.float(n)
    return (np.arange(n) + 1 - a)/(n + 1 - 2*a)

# %%
color=iter(cm.rainbow(np.linspace(0,1,len(n))))

fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)
for x in n:
    p_values=snps_gtex_cis[snps_gtex_cis["gtex cell_type"]==x].sort_values(by="pval")["pval"].tolist()
    c=next(color)
    plt.scatter(-np.log10(ppoints(len(p_values), 1./2)), -np.log10(p_values),label=x,color=c)
ax.plot([0,ax.get_xlim()[1]], [0,ax.get_xlim()[1]], ls="--", c="k")
ax.set_xlabel("Expected -log10 P value")
ax.set_ylabel('Observed -log10 P value')
plt.legend()
fig.savefig('../plots/gtex.qq.pdf')

# %%
tissue=snps_gtex_cis.pivot(index="assoc",columns="gtex cell_type",values="gtex slope")

# %%
tissue=tissue.fillna(0)

# %%
tissue=tissue.T

# %%
f=plt.figure(figsize=(20,20))
ax=sns.clustermap(tissue)

# %%
tissue_test=tissue.loc[["Brain_Cortex","Breast_Mammary_Tissue"]]

# %%
tissue_test=tissue_test.T

# %%
tissue_test["difference"]=tissue_test["Brain_Cortex"]-tissue_test["Breast_Mammary_Tissue"]

# %%
tissue_test=tissue_test.sort_values(by="difference")

# %%
plt.scatter(tissue_test.index.tolist(),tissue_test["Brain_Cortex"].tolist(),color="blue",label="brain")
plt.scatter(tissue_test.index.tolist(),tissue_test["Breast_Mammary_Tissue"].tolist(),color="red",label="breast mammary tissue")
plt.ylabel("gtex beta value")
plt.legend()

# %%
tissue
# Out:
# assoc                                  10:6077796:C:T_IL2RA  \
# gtex cell_type
# Adipose_Subcutaneous                               0.214186
# Adipose_Visceral_Omentum                           0.102967
# Adrenal_Gland                                      0.162306
# Artery_Aorta                                       0.055277
# Artery_Coronary                                    0.026545
# Artery_Tibial                                      0.111730
# Brain_Amygdala                                     0.000000
# Brain_Anterior_cingulate_cortex_BA24               0.000000
# Brain_Caudate_basal_ganglia                        0.000000
# Brain_Cerebellar_Hemisphere                        0.000000
# Brain_Cerebellum                                   0.000000
# Brain_Cortex                                       0.000000
# Brain_Frontal_Cortex_BA9                           0.000000
# Brain_Hippocampus                                  0.000000
# Brain_Hypothalamus                                 0.331141
# Brain_Nucleus_accumbens_basal_ganglia              0.000000
# Brain_Putamen_basal_ganglia                        0.000000
# Brain_Spinal_cord_cervical_c-1                     0.212271
# Brain_Substantia_nigra                             0.107868
# Breast_Mammary_Tissue                              0.091645
# Cells_Cultured_fibroblasts                         0.000000
# Cells_EBV-transformed_lymphocytes                 -0.066715
# Colon_Sigmoid                                      0.288851
# Colon_Transverse                                   0.056417
# Esophagus_Gastroesophageal_Junction                0.139613
# Esophagus_Mucosa                                   0.066129
# Esophagus_Muscularis                               0.052833
# Heart_Atrial_Appendage                             0.023602
# Heart_Left_Ventricle                               0.062177
# Kidney_Cortex                                     -0.137825
# Liver                                              0.155998
# Lung                                              -0.013172
# Minor_Salivary_Gland                              -0.088068
# Muscle_Skeletal                                    0.095270
# Nerve_Tibial                                       0.074117
# Ovary                                              0.277474
# Pancreas                                           0.251654
# Pituitary                                          0.092117
# Prostate                                           0.024029
# Skin_Not_Sun_Exposed_Suprapubic                   -0.028050
# Skin_Sun_Exposed_Lower_leg                         0.044595
# Small_Intestine_Terminal_Ileum                     0.042175
# Spleen                                             0.293738
# Stomach                                            0.128588
# Testis                                             0.054448
# Thyroid                                           -0.020327
# Uterus                                             0.096837
# Vagina                                            -0.046342
# Whole_Blood                                        0.038598
#
# assoc                                  10:6095928:C:A_IL2RA  \
# gtex cell_type
# Adipose_Subcutaneous                               0.592003
# Adipose_Visceral_Omentum                           0.419156
# Adrenal_Gland                                      0.520406
# Artery_Aorta                                       0.291532
# Artery_Coronary                                    0.312275
# Artery_Tibial                                      0.312529
# Brain_Amygdala                                     0.000000
# Brain_Anterior_cingulate_cortex_BA24               0.000000
# Brain_Caudate_basal_ganglia                        0.000000
# Brain_Cerebellar_Hemisphere                        0.000000
# Brain_Cerebellum                                   0.000000
# Brain_Cortex                                       0.000000
# Brain_Frontal_Cortex_BA9                           0.000000
# Brain_Hippocampus                                  0.000000
# Brain_Hypothalamus                                 0.673206
# Brain_Nucleus_accumbens_basal_ganglia              0.000000
# Brain_Putamen_basal_ganglia                        0.000000
# Brain_Spinal_cord_cervical_c-1                     0.524047
# Brain_Substantia_nigra                             0.501145
# Breast_Mammary_Tissue                              0.428588
# Cells_Cultured_fibroblasts                         0.000000
# Cells_EBV-transformed_lymphocytes                  0.200439
# Colon_Sigmoid                                      0.571795
# Colon_Transverse                                   0.222692
# Esophagus_Gastroesophageal_Junction                0.459507
# Esophagus_Mucosa                                   0.150053
# Esophagus_Muscularis                               0.523297
# Heart_Atrial_Appendage                             0.357182
# Heart_Left_Ventricle                               0.371236
# Kidney_Cortex                                      0.274433
# Liver                                              0.518333
# Lung                                              -0.065998
# Minor_Salivary_Gland                               0.152993
# Muscle_Skeletal                                    0.233715
# Nerve_Tibial                                       0.439516
# Ovary                                              0.416832
# Pancreas                                           0.731606
# Pituitary                                          0.234776
# Prostate                                           0.381788
# Skin_Not_Sun_Exposed_Suprapubic                   -0.024120
# Skin_Sun_Exposed_Lower_leg                         0.058512
# Small_Intestine_Terminal_Ileum                     0.073382
# Spleen                                             0.867580
# Stomach                                            0.391861
# Testis                                             0.051763
# Thyroid                                            0.099811
# Uterus                                             0.781666
# Vagina                                             0.416978
# Whole_Blood                                        0.148557
#
# assoc                                  10:75607168:T:C_SEC24C  \
# gtex cell_type
# Adipose_Subcutaneous                                 0.121819
# Adipose_Visceral_Omentum                             0.067498
# Adrenal_Gland                                        0.041263
# Artery_Aorta                                         0.045286
# Artery_Coronary                                      0.001209
# Artery_Tibial                                       -0.016389
# Brain_Amygdala                                       0.024138
# Brain_Anterior_cingulate_cortex_BA24                 0.063440
# Brain_Caudate_basal_ganglia                         -0.034647
# Brain_Cerebellar_Hemisphere                         -0.028436
# Brain_Cerebellum                                    -0.020125
# Brain_Cortex                                         0.070507
# Brain_Frontal_Cortex_BA9                            -0.034989
# Brain_Hippocampus                                   -0.024220
# Brain_Hypothalamus                                   0.052692
# Brain_Nucleus_accumbens_basal_ganglia               -0.018335
# Brain_Putamen_basal_ganglia                          0.034534
# Brain_Spinal_cord_cervical_c-1                       0.036426
# Brain_Substantia_nigra                               0.014819
# Breast_Mammary_Tissue                                0.075610
# Cells_Cultured_fibroblasts                           0.106493
# Cells_EBV-transformed_lymphocytes                    0.096684
# Colon_Sigmoid                                        0.042527
# Colon_Transverse                                     0.085320
# Esophagus_Gastroesophageal_Junction                  0.109075
# Esophagus_Mucosa                                    -0.137984
# Esophagus_Muscularis                                 0.031344
# Heart_Atrial_Appendage                               0.067192
# Heart_Left_Ventricle                                 0.020482
# Kidney_Cortex                                        0.095073
# Liver                                                0.070267
# Lung                                                 0.063627
# Minor_Salivary_Gland                                 0.188010
# Muscle_Skeletal                                      0.033839
# Nerve_Tibial                                         0.028780
# Ovary                                                0.027243
# Pancreas                                             0.084101
# Pituitary                                            0.044725
# Prostate                                            -0.012959
# Skin_Not_Sun_Exposed_Suprapubic                      0.027354
# Skin_Sun_Exposed_Lower_leg                           0.055637
# Small_Intestine_Terminal_Ileum                       0.076637
# Spleen                                               0.142053
# Stomach                                              0.152500
# Testis                                               0.035138
# Thyroid                                              0.068645
# Uterus                                              -0.029808
# Vagina                                               0.052933
# Whole_Blood                                          0.010206
#
# assoc                                  10:97603163:G:A_ENTPD1  \
# gtex cell_type
# Adipose_Subcutaneous                                 0.011570
# Adipose_Visceral_Omentum                             0.031962
# Adrenal_Gland                                       -0.067988
# Artery_Aorta                                         0.050893
# Artery_Coronary                                      0.017563
# Artery_Tibial                                       -0.024329
# Brain_Amygdala                                       0.077768
# Brain_Anterior_cingulate_cortex_BA24                 0.126058
# Brain_Caudate_basal_ganglia                          0.081059
# Brain_Cerebellar_Hemisphere                         -0.090140
# Brain_Cerebellum                                     0.059541
# Brain_Cortex                                         0.126791
# Brain_Frontal_Cortex_BA9                             0.047703
# Brain_Hippocampus                                    0.023203
# Brain_Hypothalamus                                   0.098626
# Brain_Nucleus_accumbens_basal_ganglia                0.152156
# Brain_Putamen_basal_ganglia                          0.106094
# Brain_Spinal_cord_cervical_c-1                       0.045638
# Brain_Substantia_nigra                              -0.172415
# Breast_Mammary_Tissue                                0.074526
# Cells_Cultured_fibroblasts                           0.056998
# Cells_EBV-transformed_lymphocytes                    0.877352
# Colon_Sigmoid                                       -0.043600
# Colon_Transverse                                     0.043845
# Esophagus_Gastroesophageal_Junction                  0.062101
# Esophagus_Mucosa                                     0.034265
# Esophagus_Muscularis                                 0.068542
# Heart_Atrial_Appendage                               0.006405
# Heart_Left_Ventricle                                 0.069943
# Kidney_Cortex                                       -0.014643
# Liver                                                0.212176
# Lung                                                 0.053605
# Minor_Salivary_Gland                                 0.150548
# Muscle_Skeletal                                      0.068060
# Nerve_Tibial                                        -0.039028
# Ovary                                               -0.010965
# Pancreas                                             0.080483
# Pituitary                                           -0.040588
# Prostate                                            -0.023289
# Skin_Not_Sun_Exposed_Suprapubic                      0.055891
# Skin_Sun_Exposed_Lower_leg                           0.012259
# Small_Intestine_Terminal_Ileum                       0.043704
# Spleen                                               0.381896
# Stomach                                              0.108756
# Testis                                              -0.059394
# Thyroid                                              0.075866
# Uterus                                              -0.061669
# Vagina                                              -0.039853
# Whole_Blood                                          0.038252
#
# assoc                                  10:97630523:T:C_ENTPD1  \
# gtex cell_type
# Adipose_Subcutaneous                                -0.048113
# Adipose_Visceral_Omentum                            -0.017071
# Adrenal_Gland                                        0.002276
# Artery_Aorta                                        -0.076166
# Artery_Coronary                                     -0.041424
# Artery_Tibial                                        0.000685
# Brain_Amygdala                                      -0.246478
# Brain_Anterior_cingulate_cortex_BA24                -0.286222
# Brain_Caudate_basal_ganglia                         -0.192144
# Brain_Cerebellar_Hemisphere                         -0.106248
# Brain_Cerebellum                                    -0.230550
# Brain_Cortex                                        -0.221758
# Brain_Frontal_Cortex_BA9                            -0.156628
# Brain_Hippocampus                                   -0.084744
# Brain_Hypothalamus                                  -0.166450
# Brain_Nucleus_accumbens_basal_ganglia               -0.204175
# Brain_Putamen_basal_ganglia                         -0.140786
# Brain_Spinal_cord_cervical_c-1                      -0.046181
# Brain_Substantia_nigra                               0.119119
# Breast_Mammary_Tissue                               -0.100430
# Cells_Cultured_fibroblasts                          -0.162385
# Cells_EBV-transformed_lymphocytes                   -0.656701
# Colon_Sigmoid                                       -0.002313
# Colon_Transverse                                    -0.098462
# Esophagus_Gastroesophageal_Junction                 -0.117760
# Esophagus_Mucosa                                    -0.085678
# Esophagus_Muscularis                                -0.077449
# Heart_Atrial_Appendage                              -0.053557
# Heart_Left_Ventricle                                -0.084616
# Kidney_Cortex                                        0.019611
# Liver                                               -0.289073
# Lung                                                -0.117513
# Minor_Salivary_Gland                                -0.292278
# Muscle_Skeletal                                     -0.127184
# Nerve_Tibial                                         0.005750
# Ovary                                               -0.082920
# Pancreas                                            -0.178405
# Pituitary                                           -0.030128
# Prostate                                            -0.035543
# Skin_Not_Sun_Exposed_Suprapubic                     -0.189081
# Skin_Sun_Exposed_Lower_leg                          -0.130145
# Small_Intestine_Terminal_Ileum                      -0.140108
# Spleen                                              -0.412057
# Stomach                                             -0.150456
# Testis                                              -0.084912
# Thyroid                                             -0.150330
# Uterus                                               0.032116
# Vagina                                              -0.011297
# Whole_Blood                                         -0.038739
#
# assoc                                  10:97633021:T:C_ENTPD1  \
# gtex cell_type
# Adipose_Subcutaneous                                -0.052280
# Adipose_Visceral_Omentum                            -0.012242
# Adrenal_Gland                                        0.004544
# Artery_Aorta                                        -0.076461
# Artery_Coronary                                     -0.035299
# Artery_Tibial                                        0.001859
# Brain_Amygdala                                      -0.246478
# Brain_Anterior_cingulate_cortex_BA24                -0.286222
# Brain_Caudate_basal_ganglia                         -0.192144
# Brain_Cerebellar_Hemisphere                         -0.106248
# Brain_Cerebellum                                    -0.230550
# Brain_Cortex                                        -0.221758
# Brain_Frontal_Cortex_BA9                            -0.156628
# Brain_Hippocampus                                   -0.084744
# Brain_Hypothalamus                                  -0.166450
# Brain_Nucleus_accumbens_basal_ganglia               -0.204175
# Brain_Putamen_basal_ganglia                         -0.140786
# Brain_Spinal_cord_cervical_c-1                      -0.046181
# Brain_Substantia_nigra                               0.119119
# Breast_Mammary_Tissue                               -0.095166
# Cells_Cultured_fibroblasts                          -0.162385
# Cells_EBV-transformed_lymphocytes                   -0.656701
# Colon_Sigmoid                                       -0.006293
# Colon_Transverse                                    -0.096033
# Esophagus_Gastroesophageal_Junction                 -0.121183
# Esophagus_Mucosa                                    -0.087499
# Esophagus_Muscularis                                -0.080926
# Heart_Atrial_Appendage                              -0.049495
# Heart_Left_Ventricle                                -0.089387
# Kidney_Cortex                                        0.019611
# Liver                                               -0.287034
# Lung                                                -0.113837
# Minor_Salivary_Gland                                -0.292278
# Muscle_Skeletal                                     -0.132195
# Nerve_Tibial                                         0.010456
# Ovary                                               -0.093496
# Pancreas                                            -0.177152
# Pituitary                                           -0.030128
# Prostate                                            -0.025872
# Skin_Not_Sun_Exposed_Suprapubic                     -0.192159
# Skin_Sun_Exposed_Lower_leg                          -0.126309
# Small_Intestine_Terminal_Ileum                      -0.139381
# Spleen                                              -0.412057
# Stomach                                             -0.150136
# Testis                                              -0.081068
# Thyroid                                             -0.147820
# Uterus                                               0.032116
# Vagina                                              -0.015256
# Whole_Blood                                         -0.038479
#
# assoc                                  11:10490415:T:C_AMPD3  \
# gtex cell_type
# Adipose_Subcutaneous                                0.248476
# Adipose_Visceral_Omentum                            0.095245
# Adrenal_Gland                                       0.138521
# Artery_Aorta                                        0.169344
# Artery_Coronary                                     0.163717
# Artery_Tibial                                       0.186565
# Brain_Amygdala                                      0.550128
# Brain_Anterior_cingulate_cortex_BA24                0.329180
# Brain_Caudate_basal_ganglia                         0.425145
# Brain_Cerebellar_Hemisphere                         0.016415
# Brain_Cerebellum                                    0.135679
# Brain_Cortex                                        0.359678
# Brain_Frontal_Cortex_BA9                            0.452356
# Brain_Hippocampus                                   0.360922
# Brain_Hypothalamus                                  0.341517
# Brain_Nucleus_accumbens_basal_ganglia               0.358126
# Brain_Putamen_basal_ganglia                         0.467569
# Brain_Spinal_cord_cervical_c-1                      0.626472
# Brain_Substantia_nigra                              0.545271
# Breast_Mammary_Tissue                               0.221951
# Cells_Cultured_fibroblasts                          0.092309
# Cells_EBV-transformed_lymphocytes                   0.220082
# Colon_Sigmoid                                       0.291888
# Colon_Transverse                                    0.120496
# Esophagus_Gastroesophageal_Junction                 0.467034
# Esophagus_Mucosa                                    0.405743
# Esophagus_Muscularis                                0.379948
# Heart_Atrial_Appendage                              0.182638
# Heart_Left_Ventricle                                0.287152
# Kidney_Cortex                                       0.144436
# Liver                                               0.134290
# Lung                                                0.094049
# Minor_Salivary_Gland                                0.434109
# Muscle_Skeletal                                     0.158927
# Nerve_Tibial                                        0.275233
# Ovary                                               0.286774
# Pancreas                                            0.355528
# Pituitary                                           0.069624
# Prostate                                            0.276011
# Skin_Not_Sun_Exposed_Suprapubic                    -0.020404
# Skin_Sun_Exposed_Lower_leg                          0.049381
# Small_Intestine_Terminal_Ileum                      0.146996
# Spleen                                              0.174503
# Stomach                                             0.336084
# Testis                                              0.228244
# Thyroid                                             0.262916
# Uterus                                              0.336181
# Vagina                                              0.200479
# Whole_Blood                                         0.065101
#
# assoc                                  11:60103112:T:C_MS4A4A  \
# gtex cell_type
# Adipose_Subcutaneous                                 0.120238
# Adipose_Visceral_Omentum                             0.073679
# Adrenal_Gland                                        0.105490
# Artery_Aorta                                         0.092164
# Artery_Coronary                                      0.143338
# Artery_Tibial                                        0.113623
# Brain_Amygdala                                       0.108366
# Brain_Anterior_cingulate_cortex_BA24                 0.098439
# Brain_Caudate_basal_ganglia                          0.203596
# Brain_Cerebellar_Hemisphere                          0.070539
# Brain_Cerebellum                                     0.151848
# Brain_Cortex                                         0.135261
# Brain_Frontal_Cortex_BA9                             0.184214
# Brain_Hippocampus                                    0.225408
# Brain_Hypothalamus                                   0.126734
# Brain_Nucleus_accumbens_basal_ganglia                0.127241
# Brain_Putamen_basal_ganglia                          0.214158
# Brain_Spinal_cord_cervical_c-1                       0.235370
# Brain_Substantia_nigra                               0.209721
# Breast_Mammary_Tissue                                0.086727
# Cells_Cultured_fibroblasts                           0.000000
# Cells_EBV-transformed_lymphocytes                   -0.073601
# Colon_Sigmoid                                        0.148717
# Colon_Transverse                                     0.090336
# Esophagus_Gastroesophageal_Junction                  0.069693
# Esophagus_Mucosa                                     0.071837
# Esophagus_Muscularis                                 0.100401
# Heart_Atrial_Appendage                               0.071339
# Heart_Left_Ventricle                                 0.089427
# Kidney_Cortex                                        0.255987
# Liver                                                0.102153
# Lung                                                 0.074145
# Minor_Salivary_Gland                                 0.167504
# Muscle_Skeletal                                      0.069269
# Nerve_Tibial                                         0.135711
# Ovary                                                0.046518
# Pancreas                                             0.225942
# Pituitary                                            0.129795
# Prostate                                             0.178736
# Skin_Not_Sun_Exposed_Suprapubic                      0.068533
# Skin_Sun_Exposed_Lower_leg                           0.049263
# Small_Intestine_Terminal_Ileum                       0.163565
# Spleen                                               0.156459
# Stomach                                              0.118241
# Testis                                               0.198645
# Thyroid                                              0.109427
# Uterus                                              -0.078793
# Vagina                                               0.087982
# Whole_Blood                                          0.026198
#
# assoc                                  11:64885445:C:A_CTSW  \
# gtex cell_type
# Adipose_Subcutaneous                               0.038116
# Adipose_Visceral_Omentum                           0.169572
# Adrenal_Gland                                     -0.046242
# Artery_Aorta                                       0.139008
# Artery_Coronary                                    0.162614
# Artery_Tibial                                      0.040712
# Brain_Amygdala                                     0.063270
# Brain_Anterior_cingulate_cortex_BA24               0.081605
# Brain_Caudate_basal_ganglia                        0.172721
# Brain_Cerebellar_Hemisphere                        0.085094
# Brain_Cerebellum                                  -0.109298
# Brain_Cortex                                       0.227036
# Brain_Frontal_Cortex_BA9                           0.012958
# Brain_Hippocampus                                  0.128939
# Brain_Hypothalamus                                 0.132494
# Brain_Nucleus_accumbens_basal_ganglia              0.189442
# Brain_Putamen_basal_ganglia                        0.142766
# Brain_Spinal_cord_cervical_c-1                     0.077131
# Brain_Substantia_nigra                            -0.001972
# Breast_Mammary_Tissue                              0.198091
# Cells_Cultured_fibroblasts                         0.018812
# Cells_EBV-transformed_lymphocytes                  0.079314
# Colon_Sigmoid                                      0.098122
# Colon_Transverse                                   0.079248
# Esophagus_Gastroesophageal_Junction                0.137523
# Esophagus_Mucosa                                   0.121830
# Esophagus_Muscularis                               0.113294
# Heart_Atrial_Appendage                             0.146482
# Heart_Left_Ventricle                               0.098557
# Kidney_Cortex                                      0.113759
# Liver                                              0.100346
# Lung                                               0.127529
# Minor_Salivary_Gland                               0.068312
# Muscle_Skeletal                                   -0.012942
# Nerve_Tibial                                       0.168125
# Ovary                                              0.079479
# Pancreas                                           0.108396
# Pituitary                                          0.050567
# Prostate                                           0.204578
# Skin_Not_Sun_Exposed_Suprapubic                    0.141184
# Skin_Sun_Exposed_Lower_leg                         0.125917
# Small_Intestine_Terminal_Ileum                     0.257282
# Spleen                                             0.252155
# Stomach                                            0.165282
# Testis                                             0.001530
# Thyroid                                            0.085393
# Uterus                                             0.111435
# Vagina                                             0.162720
# Whole_Blood                                        0.052238
#
# assoc                                  11:64908332:A:C_CTSW  ...  \
# gtex cell_type                                               ...
# Adipose_Subcutaneous                              -0.142123  ...
# Adipose_Visceral_Omentum                          -0.128182  ...
# Adrenal_Gland                                     -0.353951  ...
# Artery_Aorta                                      -0.092482  ...
# Artery_Coronary                                   -0.232527  ...
# Artery_Tibial                                     -0.143730  ...
# Brain_Amygdala                                    -0.006449  ...
# Brain_Anterior_cingulate_cortex_BA24              -0.048675  ...
# Brain_Caudate_basal_ganglia                        0.140746  ...
# Brain_Cerebellar_Hemisphere                        0.076429  ...
# Brain_Cerebellum                                  -0.070677  ...
# Brain_Cortex                                      -0.392102  ...
# Brain_Frontal_Cortex_BA9                          -0.116064  ...
# Brain_Hippocampus                                 -0.003919  ...
# Brain_Hypothalamus                                 0.132154  ...
# Brain_Nucleus_accumbens_basal_ganglia             -0.269677  ...
# Brain_Putamen_basal_ganglia                        0.111790  ...
# Brain_Spinal_cord_cervical_c-1                    -0.080137  ...
# Brain_Substantia_nigra                            -0.157583  ...
# Breast_Mammary_Tissue                             -0.360394  ...
# Cells_Cultured_fibroblasts                        -0.209926  ...
# Cells_EBV-transformed_lymphocytes                 -1.218532  ...
# Colon_Sigmoid                                     -0.211323  ...
# Colon_Transverse                                  -0.231505  ...
# Esophagus_Gastroesophageal_Junction               -0.122071  ...
# Esophagus_Mucosa                                  -0.081938  ...
# Esophagus_Muscularis                              -0.020171  ...
# Heart_Atrial_Appendage                             0.001971  ...
# Heart_Left_Ventricle                              -0.169107  ...
# Kidney_Cortex                                      0.028884  ...
# Liver                                             -0.250658  ...
# Lung                                              -0.056293  ...
# Minor_Salivary_Gland                              -0.097527  ...
# Muscle_Skeletal                                   -0.235316  ...
# Nerve_Tibial                                      -0.230387  ...
# Ovary                                             -0.275063  ...
# Pancreas                                          -0.194146  ...
# Pituitary                                         -0.269377  ...
# Prostate                                          -0.060719  ...
# Skin_Not_Sun_Exposed_Suprapubic                   -0.203412  ...
# Skin_Sun_Exposed_Lower_leg                        -0.175312  ...
# Small_Intestine_Terminal_Ileum                     0.107766  ...
# Spleen                                            -0.150161  ...
# Stomach                                           -0.424917  ...
# Testis                                             0.398187  ...
# Thyroid                                           -0.246556  ...
# Uterus                                            -0.331732  ...
# Vagina                                            -0.972803  ...
# Whole_Blood                                       -0.179669  ...
#
# assoc                                  6:159042876:C:A_DYNLT1  \
# gtex cell_type
# Adipose_Subcutaneous                                 0.194109
# Adipose_Visceral_Omentum                             0.161332
# Adrenal_Gland                                        0.391024
# Artery_Aorta                                        -0.114649
# Artery_Coronary                                      0.094597
# Artery_Tibial                                        0.136619
# Brain_Amygdala                                       0.112356
# Brain_Anterior_cingulate_cortex_BA24                 0.056593
# Brain_Caudate_basal_ganglia                         -0.023120
# Brain_Cerebellar_Hemisphere                          0.037224
# Brain_Cerebellum                                     0.007826
# Brain_Cortex                                         0.063462
# Brain_Frontal_Cortex_BA9                             0.067559
# Brain_Hippocampus                                    0.037723
# Brain_Hypothalamus                                   0.115887
# Brain_Nucleus_accumbens_basal_ganglia                0.051870
# Brain_Putamen_basal_ganglia                          0.075010
# Brain_Spinal_cord_cervical_c-1                       0.141585
# Brain_Substantia_nigra                               0.094074
# Breast_Mammary_Tissue                                0.155300
# Cells_Cultured_fibroblasts                           0.139455
# Cells_EBV-transformed_lymphocytes                    0.018296
# Colon_Sigmoid                                        0.106245
# Colon_Transverse                                     0.129334
# Esophagus_Gastroesophageal_Junction                  0.148740
# Esophagus_Mucosa                                    -0.012422
# Esophagus_Muscularis                                 0.133483
# Heart_Atrial_Appendage                              -0.069154
# Heart_Left_Ventricle                                -0.027969
# Kidney_Cortex                                        0.014124
# Liver                                                0.261085
# Lung                                                 0.068092
# Minor_Salivary_Gland                                 0.044880
# Muscle_Skeletal                                     -0.071701
# Nerve_Tibial                                         0.262728
# Ovary                                                0.134945
# Pancreas                                             0.194293
# Pituitary                                            0.214800
# Prostate                                             0.048795
# Skin_Not_Sun_Exposed_Suprapubic                     -0.092234
# Skin_Sun_Exposed_Lower_leg                          -0.049475
# Small_Intestine_Terminal_Ileum                       0.141733
# Spleen                                              -0.014278
# Stomach                                              0.158360
# Testis                                               0.109774
# Thyroid                                              0.317999
# Uterus                                               0.010658
# Vagina                                               0.173491
# Whole_Blood                                         -0.095138
#
# assoc                                  6:159072350:C:T_DYNLT1  \
# gtex cell_type
# Adipose_Subcutaneous                                -0.245483
# Adipose_Visceral_Omentum                            -0.216332
# Adrenal_Gland                                       -0.569594
# Artery_Aorta                                         0.077967
# Artery_Coronary                                     -0.133729
# Artery_Tibial                                       -0.195008
# Brain_Amygdala                                      -0.026979
# Brain_Anterior_cingulate_cortex_BA24                -0.079082
# Brain_Caudate_basal_ganglia                         -0.018095
# Brain_Cerebellar_Hemisphere                         -0.058940
# Brain_Cerebellum                                    -0.020058
# Brain_Cortex                                        -0.089047
# Brain_Frontal_Cortex_BA9                            -0.080274
# Brain_Hippocampus                                   -0.018450
# Brain_Hypothalamus                                  -0.101929
# Brain_Nucleus_accumbens_basal_ganglia               -0.074918
# Brain_Putamen_basal_ganglia                         -0.082194
# Brain_Spinal_cord_cervical_c-1                      -0.131688
# Brain_Substantia_nigra                              -0.077516
# Breast_Mammary_Tissue                               -0.219477
# Cells_Cultured_fibroblasts                          -0.164866
# Cells_EBV-transformed_lymphocytes                   -0.104869
# Colon_Sigmoid                                       -0.135094
# Colon_Transverse                                    -0.216650
# Esophagus_Gastroesophageal_Junction                 -0.151613
# Esophagus_Mucosa                                     0.063615
# Esophagus_Muscularis                                -0.174708
# Heart_Atrial_Appendage                               0.046922
# Heart_Left_Ventricle                                 0.068673
# Kidney_Cortex                                       -0.044754
# Liver                                               -0.219904
# Lung                                                -0.076474
# Minor_Salivary_Gland                                -0.071715
# Muscle_Skeletal                                      0.056900
# Nerve_Tibial                                        -0.316621
# Ovary                                               -0.112913
# Pancreas                                            -0.192546
# Pituitary                                           -0.333144
# Prostate                                            -0.097425
# Skin_Not_Sun_Exposed_Suprapubic                      0.210361
# Skin_Sun_Exposed_Lower_leg                           0.102476
# Small_Intestine_Terminal_Ileum                      -0.093440
# Spleen                                              -0.007992
# Stomach                                             -0.160444
# Testis                                              -0.140077
# Thyroid                                             -0.361359
# Uterus                                              -0.049860
# Vagina                                              -0.074241
# Whole_Blood                                          0.123956
#
# assoc                                  6:160272430:C:T_IGF2R  \
# gtex cell_type
# Adipose_Subcutaneous                                0.183401
# Adipose_Visceral_Omentum                           -0.121536
# Adrenal_Gland                                      -0.027016
# Artery_Aorta                                        0.324482
# Artery_Coronary                                     0.171479
# Artery_Tibial                                       0.088827
# Brain_Amygdala                                      0.169663
# Brain_Anterior_cingulate_cortex_BA24               -0.135858
# Brain_Caudate_basal_ganglia                        -0.089233
# Brain_Cerebellar_Hemisphere                        -0.097057
# Brain_Cerebellum                                    0.022295
# Brain_Cortex                                        0.522417
# Brain_Frontal_Cortex_BA9                            0.074479
# Brain_Hippocampus                                   0.010391
# Brain_Hypothalamus                                  0.152218
# Brain_Nucleus_accumbens_basal_ganglia               0.084003
# Brain_Putamen_basal_ganglia                         0.240579
# Brain_Spinal_cord_cervical_c-1                      0.095678
# Brain_Substantia_nigra                              0.109104
# Breast_Mammary_Tissue                               0.055520
# Cells_Cultured_fibroblasts                         -0.056874
# Cells_EBV-transformed_lymphocytes                   0.097704
# Colon_Sigmoid                                       0.291766
# Colon_Transverse                                    0.092172
# Esophagus_Gastroesophageal_Junction                 0.065815
# Esophagus_Mucosa                                   -0.062786
# Esophagus_Muscularis                               -0.152618
# Heart_Atrial_Appendage                              0.208663
# Heart_Left_Ventricle                                0.002812
# Kidney_Cortex                                       0.097894
# Liver                                              -0.066764
# Lung                                                0.041493
# Minor_Salivary_Gland                                0.066765
# Muscle_Skeletal                                    -0.036469
# Nerve_Tibial                                        0.107983
# Ovary                                               0.028060
# Pancreas                                           -0.065420
# Pituitary                                           0.053685
# Prostate                                            0.329097
# Skin_Not_Sun_Exposed_Suprapubic                    -0.019760
# Skin_Sun_Exposed_Lower_leg                          0.200276
# Small_Intestine_Terminal_Ileum                     -0.161508
# Spleen                                             -0.236902
# Stomach                                            -0.030160
# Testis                                              0.001788
# Thyroid                                             0.058445
# Uterus                                              0.012245
# Vagina                                             -0.056700
# Whole_Blood                                         0.020693
#
# assoc                                  6:160511354:G:A_IGF2R  \
# gtex cell_type
# Adipose_Subcutaneous                                0.090160
# Adipose_Visceral_Omentum                            0.055048
# Adrenal_Gland                                       0.107976
# Artery_Aorta                                        0.243379
# Artery_Coronary                                     0.190007
# Artery_Tibial                                       0.183849
# Brain_Amygdala                                      0.062488
# Brain_Anterior_cingulate_cortex_BA24                0.054506
# Brain_Caudate_basal_ganglia                         0.016980
# Brain_Cerebellar_Hemisphere                         0.004532
# Brain_Cerebellum                                    0.018713
# Brain_Cortex                                        0.069017
# Brain_Frontal_Cortex_BA9                            0.009344
# Brain_Hippocampus                                  -0.118349
# Brain_Hypothalamus                                  0.024012
# Brain_Nucleus_accumbens_basal_ganglia               0.075896
# Brain_Putamen_basal_ganglia                         0.103615
# Brain_Spinal_cord_cervical_c-1                     -0.061260
# Brain_Substantia_nigra                              0.198023
# Breast_Mammary_Tissue                              -0.006211
# Cells_Cultured_fibroblasts                          0.138977
# Cells_EBV-transformed_lymphocytes                  -0.193983
# Colon_Sigmoid                                       0.093839
# Colon_Transverse                                    0.050964
# Esophagus_Gastroesophageal_Junction                 0.084267
# Esophagus_Mucosa                                    0.014083
# Esophagus_Muscularis                                0.045691
# Heart_Atrial_Appendage                              0.140699
# Heart_Left_Ventricle                                0.042275
# Kidney_Cortex                                       0.166899
# Liver                                              -0.028909
# Lung                                                0.068912
# Minor_Salivary_Gland                                0.108832
# Muscle_Skeletal                                    -0.053259
# Nerve_Tibial                                        0.089658
# Ovary                                               0.020014
# Pancreas                                           -0.030079
# Pituitary                                           0.100235
# Prostate                                            0.037788
# Skin_Not_Sun_Exposed_Suprapubic                     0.015904
# Skin_Sun_Exposed_Lower_leg                          0.023678
# Small_Intestine_Terminal_Ileum                      0.042196
# Spleen                                             -0.033309
# Stomach                                             0.124615
# Testis                                              0.041847
# Thyroid                                             0.059265
# Uterus                                              0.135473
# Vagina                                             -0.007410
# Whole_Blood                                        -0.018065
#
# assoc                                  6:24403549:C:A_GPLD1  \
# gtex cell_type
# Adipose_Subcutaneous                               0.170900
# Adipose_Visceral_Omentum                           0.206663
# Adrenal_Gland                                      0.094504
# Artery_Aorta                                       0.229029
# Artery_Coronary                                    0.306828
# Artery_Tibial                                      0.417752
# Brain_Amygdala                                     0.305818
# Brain_Anterior_cingulate_cortex_BA24               0.191818
# Brain_Caudate_basal_ganglia                        0.206541
# Brain_Cerebellar_Hemisphere                        0.029131
# Brain_Cerebellum                                   0.021052
# Brain_Cortex                                       0.076480
# Brain_Frontal_Cortex_BA9                           0.108180
# Brain_Hippocampus                                  0.088068
# Brain_Hypothalamus                                 0.228237
# Brain_Nucleus_accumbens_basal_ganglia              0.127139
# Brain_Putamen_basal_ganglia                        0.274187
# Brain_Spinal_cord_cervical_c-1                     0.196831
# Brain_Substantia_nigra                             0.184065
# Breast_Mammary_Tissue                              0.345385
# Cells_Cultured_fibroblasts                         0.194825
# Cells_EBV-transformed_lymphocytes                  0.295003
# Colon_Sigmoid                                      0.405403
# Colon_Transverse                                   0.152054
# Esophagus_Gastroesophageal_Junction                0.307532
# Esophagus_Mucosa                                   0.845211
# Esophagus_Muscularis                               0.384181
# ...
# Adrenal_Gland                                      0.018970
# Artery_Aorta                                      -0.174559
# Artery_Coronary                                    0.142258
# Artery_Tibial                                      0.184988
# Brain_Amygdala                                     0.170170
# Brain_Anterior_cingulate_cortex_BA24               0.052575
# Brain_Caudate_basal_ganglia                       -0.117333
# Brain_Cerebellar_Hemisphere                       -0.001845
# Brain_Cerebellum                                  -0.104944
# Brain_Cortex                                      -0.101155
# Brain_Frontal_Cortex_BA9                          -0.032128
# Brain_Hippocampus                                  0.030530
# Brain_Hypothalamus                                 0.028281
# Brain_Nucleus_accumbens_basal_ganglia             -0.039518
# Brain_Putamen_basal_ganglia                        0.100782
# Brain_Spinal_cord_cervical_c-1                     0.071376
# Brain_Substantia_nigra                            -0.079037
# Breast_Mammary_Tissue                              0.327309
# Cells_Cultured_fibroblasts                         0.142170
# Cells_EBV-transformed_lymphocytes                  0.025688
# Colon_Sigmoid                                      0.227898
# Colon_Transverse                                   0.064220
# Esophagus_Gastroesophageal_Junction                0.223152
# Esophagus_Mucosa                                   1.059157
# Esophagus_Muscularis                               0.136114
# Heart_Atrial_Appendage                             0.147322
# Heart_Left_Ventricle                               0.025688
# Kidney_Cortex                                      0.347564
# Liver                                             -0.009006
# Lung                                               0.016696
# Minor_Salivary_Gland                               0.157878
# Muscle_Skeletal                                   -0.195451
# Nerve_Tibial                                       0.174546
# Ovary                                              0.161814
# Pancreas                                           0.235398
# Pituitary                                          0.028044
# Prostate                                           0.610442
# Skin_Not_Sun_Exposed_Suprapubic                    0.440002
# Skin_Sun_Exposed_Lower_leg                         0.216082
# Small_Intestine_Terminal_Ileum                     0.004298
# Spleen                                             0.162701
# Stomach                                            0.019148
# Testis                                             0.334722
# Thyroid                                            0.235482
# Uterus                                             0.022633
# Vagina                                             0.507997
# Whole_Blood                                       -0.162740
#
# assoc                                  6:24560002:A:T_GPLD1  \
# gtex cell_type
# Adipose_Subcutaneous                               0.016010
# Adipose_Visceral_Omentum                           0.003702
# Adrenal_Gland                                      0.068893
# Artery_Aorta                                      -0.054109
# Artery_Coronary                                    0.130738
# Artery_Tibial                                      0.123517
# Brain_Amygdala                                     0.068031
# Brain_Anterior_cingulate_cortex_BA24              -0.057786
# Brain_Caudate_basal_ganglia                       -0.101307
# Brain_Cerebellar_Hemisphere                       -0.036510
# Brain_Cerebellum                                  -0.071597
# Brain_Cortex                                      -0.029917
# Brain_Frontal_Cortex_BA9                          -0.026569
# Brain_Hippocampus                                  0.017310
# Brain_Hypothalamus                                -0.002858
# Brain_Nucleus_accumbens_basal_ganglia             -0.080016
# Brain_Putamen_basal_ganglia                        0.063676
# Brain_Spinal_cord_cervical_c-1                     0.001433
# Brain_Substantia_nigra                            -0.096093
# Breast_Mammary_Tissue                              0.150405
# Cells_Cultured_fibroblasts                         0.155401
# Cells_EBV-transformed_lymphocytes                 -0.138700
# Colon_Sigmoid                                      0.216291
# Colon_Transverse                                   0.013760
# Esophagus_Gastroesophageal_Junction                0.203269
# Esophagus_Mucosa                                   0.566342
# Esophagus_Muscularis                               0.133466
# Heart_Atrial_Appendage                             0.112894
# Heart_Left_Ventricle                              -0.040393
# Kidney_Cortex                                     -0.007453
# Liver                                              0.052855
# Lung                                              -0.035597
# Minor_Salivary_Gland                               0.095985
# Muscle_Skeletal                                   -0.163984
# Nerve_Tibial                                       0.081667
# Ovary                                              0.155999
# Pancreas                                           0.045742
# Pituitary                                         -0.036096
# Prostate                                           0.384307
# Skin_Not_Sun_Exposed_Suprapubic                    0.155692
# Skin_Sun_Exposed_Lower_leg                         0.047025
# Small_Intestine_Terminal_Ileum                     0.017320
# Spleen                                             0.049421
# Stomach                                           -0.082271
# Testis                                             0.193293
# Thyroid                                            0.023957
# Uterus                                             0.066487
# Vagina                                             0.192116
# Whole_Blood                                       -0.001616
#
# assoc                                  7:6067019:A:C_EIF2AK1  \
# gtex cell_type
# Adipose_Subcutaneous                               -0.102954
# Adipose_Visceral_Omentum                           -0.100460
# Adrenal_Gland                                      -0.280687
# Artery_Aorta                                       -0.152341
# Artery_Coronary                                    -0.080261
# Artery_Tibial                                      -0.164202
# Brain_Amygdala                                     -0.160049
# Brain_Anterior_cingulate_cortex_BA24               -0.434383
# Brain_Caudate_basal_ganglia                        -0.412675
# Brain_Cerebellar_Hemisphere                        -0.184972
# Brain_Cerebellum                                   -0.246057
# Brain_Cortex                                       -0.423631
# Brain_Frontal_Cortex_BA9                           -0.399445
# Brain_Hippocampus                                  -0.288891
# Brain_Hypothalamus                                 -0.314824
# Brain_Nucleus_accumbens_basal_ganglia              -0.392275
# Brain_Putamen_basal_ganglia                        -0.410419
# Brain_Spinal_cord_cervical_c-1                     -0.308419
# Brain_Substantia_nigra                             -0.279097
# Breast_Mammary_Tissue                              -0.000413
# Cells_Cultured_fibroblasts                         -0.224577
# Cells_EBV-transformed_lymphocytes                  -0.660790
# Colon_Sigmoid                                      -0.106111
# Colon_Transverse                                   -0.031946
# Esophagus_Gastroesophageal_Junction                -0.070399
# Esophagus_Mucosa                                   -0.075876
# Esophagus_Muscularis                               -0.059832
# Heart_Atrial_Appendage                             -0.295178
# Heart_Left_Ventricle                               -0.130733
# Kidney_Cortex                                      -0.274605
# Liver                                               0.074258
# Lung                                               -0.084370
# Minor_Salivary_Gland                               -0.061090
# Muscle_Skeletal                                    -0.124628
# Nerve_Tibial                                       -0.058214
# Ovary                                               0.074214
# Pancreas                                            0.210440
# Pituitary                                          -0.247599
# Prostate                                           -0.086029
# Skin_Not_Sun_Exposed_Suprapubic                    -0.078656
# Skin_Sun_Exposed_Lower_leg                         -0.055461
# Small_Intestine_Terminal_Ileum                     -0.078136
# Spleen                                             -0.067903
# Stomach                                             0.006224
# Testis                                              0.016323
# Thyroid                                            -0.038116
# Uterus                                              0.031656
# Vagina                                             -0.036923
# Whole_Blood                                        -0.051814
#
# assoc                                  8:11309400:C:T_FAM167A  \
# gtex cell_type
# Adipose_Subcutaneous                                -0.143770
# Adipose_Visceral_Omentum                            -0.050569
# Adrenal_Gland                                        0.042469
# Artery_Aorta                                        -0.249461
# Artery_Coronary                                     -0.020872
# Artery_Tibial                                        0.000000
# Brain_Amygdala                                       0.173479
# Brain_Anterior_cingulate_cortex_BA24                 0.064433
# Brain_Caudate_basal_ganglia                          0.131890
# Brain_Cerebellar_Hemisphere                          0.106327
# Brain_Cerebellum                                     0.028065
# Brain_Cortex                                         0.087355
# Brain_Frontal_Cortex_BA9                             0.061133
# Brain_Hippocampus                                    0.141564
# Brain_Hypothalamus                                   0.116423
# Brain_Nucleus_accumbens_basal_ganglia                0.090324
# Brain_Putamen_basal_ganglia                          0.215435
# Brain_Spinal_cord_cervical_c-1                       0.061737
# Brain_Substantia_nigra                               0.103085
# Breast_Mammary_Tissue                                0.029864
# Cells_Cultured_fibroblasts                          -0.137879
# Cells_EBV-transformed_lymphocytes                   -0.465346
# Colon_Sigmoid                                        0.011105
# Colon_Transverse                                     0.081435
# Esophagus_Gastroesophageal_Junction                  0.064477
# Esophagus_Mucosa                                    -0.325893
# Esophagus_Muscularis                                 0.096072
# Heart_Atrial_Appendage                               0.075321
# Heart_Left_Ventricle                                 0.000000
# Kidney_Cortex                                       -0.236881
# Liver                                               -0.167170
# Lung                                                 0.011090
# Minor_Salivary_Gland                                -0.166280
# Muscle_Skeletal                                      0.000000
# Nerve_Tibial                                         0.127933
# Ovary                                                0.132947
# Pancreas                                            -0.011103
# Pituitary                                            0.036362
# Prostate                                            -0.063151
# Skin_Not_Sun_Exposed_Suprapubic                      0.048921
# Skin_Sun_Exposed_Lower_leg                           0.120259
# Small_Intestine_Terminal_Ileum                      -0.034947
# Spleen                                              -0.220309
# Stomach                                             -0.044713
# Testis                                               0.076166
# Thyroid                                              0.070836
# Uterus                                              -0.012680
# Vagina                                              -0.055735
# Whole_Blood                                         -0.204660
#
# assoc                                  9:127095703:G:A_PSMB7
# gtex cell_type
# Adipose_Subcutaneous                               -0.077955
# Adipose_Visceral_Omentum                           -0.165650
# Adrenal_Gland                                       0.199814
# Artery_Aorta                                        0.027684
# Artery_Coronary                                     0.123221
# Artery_Tibial                                      -0.031749
# Brain_Amygdala                                     -0.159383
# Brain_Anterior_cingulate_cortex_BA24                0.097551
# Brain_Caudate_basal_ganglia                        -0.005585
# Brain_Cerebellar_Hemisphere                         0.044765
# Brain_Cerebellum                                    0.276271
# Brain_Cortex                                        0.000772
# Brain_Frontal_Cortex_BA9                           -0.064664
# Brain_Hippocampus                                   0.018473
# Brain_Hypothalamus                                 -0.112020
# Brain_Nucleus_accumbens_basal_ganglia               0.000604
# Brain_Putamen_basal_ganglia                         0.129002
# Brain_Spinal_cord_cervical_c-1                      0.196455
# Brain_Substantia_nigra                             -0.237579
# Breast_Mammary_Tissue                              -0.084913
# Cells_Cultured_fibroblasts                         -0.153298
# Cells_EBV-transformed_lymphocytes                  -0.317097
# Colon_Sigmoid                                       0.031293
# Colon_Transverse                                   -0.052986
# Esophagus_Gastroesophageal_Junction                 0.150911
# Esophagus_Mucosa                                   -0.096020
# Esophagus_Muscularis                               -0.107662
# Heart_Atrial_Appendage                              0.071184
# Heart_Left_Ventricle                                0.074126
# Kidney_Cortex                                       0.002485
# Liver                                              -0.158795
# Lung                                               -0.112747
# Minor_Salivary_Gland                               -0.181395
# Muscle_Skeletal                                    -0.003083
# Nerve_Tibial                                       -0.126066
# Ovary                                              -0.229065
# Pancreas                                           -0.077125
# Pituitary                                           0.019844
# Prostate                                           -0.083036
# Skin_Not_Sun_Exposed_Suprapubic                    -0.092359
# Skin_Sun_Exposed_Lower_leg                         -0.079884
# Small_Intestine_Terminal_Ileum                      0.015125
# Spleen                                             -0.219159
# Stomach                                            -0.033879
# Testis                                             -0.149876
# Thyroid                                            -0.074672
# Uterus                                             -0.222800
# Vagina                                             -0.157060
# Whole_Blood                                        -0.084303
#
# [49 rows x 364 columns]

# %% [markdown]
# ## Get TCGA association analyses by cancer for each RNA processing pipeline

# %%
tpm_cancer=pd.read_csv("/cellar/users/mpagadal/Data/projects/germline-immune/snp-tables/tpm.cancer.tsv",delimiter="\t")
firebrowse_cancer=pd.read_csv("/cellar/users/mpagadal/Data/projects/germline-immune/snp-tables/firebrowse.cancer.tsv",delimiter="\t")
pancanatlas_cancer=pd.read_csv("/cellar/users/mpagadal/Data/projects/germline-immune/snp-tables/pancanatlas.cancer.tsv",delimiter="\t")

# %% [markdown]
# ## See concordance between associations

# %%
def make_bootstrapping_df(df,name,combos):
    compare_beta=pd.merge(snps_gtex_cis,df,on="assoc")
    compare_beta["combo"]=compare_beta["gtex cell_type"]+"."+compare_beta["file_name"]
    if combos == "regular":
        compare_beta=compare_beta[compare_beta["combo"].isin(tissue_mapping["combo"].tolist())]
    if combos == "blood":
        compare_beta=compare_beta[compare_beta["combo"].isin(tissue_mapping["whole_blood combo"].tolist())]
    
    compare_beta["z_score"]=(compare_beta["gtex slope"]-compare_beta["BETA"])/compare_beta["gtex slope_se"]
    
    for x in compare_beta["combo"].unique():
        test=compare_beta[compare_beta["combo"]==x]
        test["z_score"]=abs(test["z_score"])
        test.to_csv(name+"."+x+".csv")

# %%
make_bootstrapping_df(tpm_cancer,"/cellar/users/mpagadal/Data/gtex/for_bootstrapping/brian_bootstrap/brian.test","regular")
make_bootstrapping_df(firebrowse_cancer,"/cellar/users/mpagadal/Data/gtex/for_bootstrapping/firebrowse_bootstrap/firebrowse.test","regular")
make_bootstrapping_df(pancanatlas_cancer,"/cellar/users/mpagadal/Data/gtex/for_bootstrapping/pancanatlas_bootstrap/pancanatlas.test","regular")
# Out:
# /nrnb/opt/anaconda3.7/lib/python3.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]

# %%
make_bootstrapping_df(tpm_cancer,"/cellar/users/mpagadal/Data/gtex/for_bootstrapping/brian_bootstrap/brian.test","blood")
make_bootstrapping_df(firebrowse_cancer,"/cellar/users/mpagadal/Data/gtex/for_bootstrapping/firebrowse_bootstrap/firebrowse.test","blood")
make_bootstrapping_df(pancanatlas_cancer,"/cellar/users/mpagadal/Data/gtex/for_bootstrapping/pancanatlas_bootstrap/pancanatlas.test","blood")
# Out:
# /nrnb/opt/anaconda3.7/lib/python3.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   del sys.path[0]

# %% [markdown]
# ## Get dataframe from bootstrapping

# %%
def make_deviant_df(directory,name,threshold):
    files=[x for x in os.listdir(directory) if "bootstrap" in x]
    
    deviant=pd.DataFrame()

    for x in files:
        boot=pd.read_csv(directory+"/"+x)
        df=boot[boot["bootstrap p"]<threshold]
        deviant=deviant.append(df)
        
    return(deviant)

# %%
brian_deviant=make_deviant_df("/cellar/users/mpagadal/Data/gtex/for_bootstrapping/brian_bootstrap","brian",.01)
firebrowse_deviant=make_deviant_df("/cellar/users/mpagadal/Data/gtex/for_bootstrapping/firebrowse_bootstrap","firebrowse",.01)
pancanatlas_deviant=make_deviant_df("/cellar/users/mpagadal/Data/gtex/for_bootstrapping/pancanatlas_bootstrap","pancanatlas",.01)

# %%
brian_immune_deviant=brian_deviant[brian_deviant["gtex cell_type"]=="Whole_Blood"]
brian_match_deviant=brian_deviant[brian_deviant["gtex cell_type"]!="Whole_Blood"]

# %%
firebrowse_immune_deviant=firebrowse_deviant[firebrowse_deviant["gtex cell_type"]=="Whole_Blood"]
firebrowse_match_deviant=firebrowse_deviant[firebrowse_deviant["gtex cell_type"]!="Whole_Blood"]

# %%
pancanatlas_immune_deviant=pancanatlas_deviant[pancanatlas_deviant["gtex cell_type"]=="Whole_Blood"]
pancanatlas_match_deviant=pancanatlas_deviant[pancanatlas_deviant["gtex cell_type"]!="Whole_Blood"]

# %%
pancanatlas_match_deviant
# Out:
#      Unnamed: 0  Unnamed: 0.1          gene_id  gtex slope  gtex slope_se ref  \
# 32           32         47202  ENSG00000163131    0.516874       0.071880   C
# 33           33         48672  ENSG00000163131    0.481948       0.070521   G
# 34           34         50142  ENSG00000163131    0.481948       0.070521   T
# 115         115        167682  ENSG00000164307    0.145819       0.053531   A
# 121         121        176502  ENSG00000164307   -0.024520       0.063306   T
# ..          ...           ...              ...         ...            ...  ..
# 136         136        199645  ENSG00000164308    0.438607       0.261923   G
# 156         156        229045  ENSG00000164308   -0.463646       0.239539   A
# 280         280        409795  ENSG00000167613   -0.067293       0.111285   G
# 314         314        459175  ENSG00000145416    0.523876       0.036382   G
# 350         350        511585  ENSG00000166847    0.066897       0.099383   C
#
#     alt               gtex cell_type          pval  gtex maf  ...  OBS_CT  \
# 32    T  Brain_Cerebellar_Hemisphere  6.566587e-11  0.423567  ...     430
# 33    A  Brain_Cerebellar_Hemisphere  3.951236e-10  0.410828  ...     430
# 34    C  Brain_Cerebellar_Hemisphere  3.951236e-10  0.410828  ...     430
# 115   G  Brain_Cerebellar_Hemisphere  7.438915e-03  0.261147  ...     430
# 121   C  Brain_Cerebellar_Hemisphere  6.992208e-01  0.194268  ...     430
# ..   ..                          ...           ...       ...  ...     ...
# 136   A                       Testis  9.545377e-02  0.016544  ...     108
# 156   G                       Testis  5.421258e-02  0.025735  ...     108
# 280   A                       Testis  5.460112e-01  0.040441  ...     108
# 314   A                       Testis  1.760040e-33  0.397059  ...     108
# 350   G                       Testis  5.015785e-01  0.022059  ...     108
#
#          BETA        SE    T_STAT             P           ERRCODE   pheno  \
# 32   0.115477  0.068827  1.677780  9.414030e-02                 .    CTSS
# 33   0.102251  0.069174  1.478170  1.401200e-01                 .    CTSS
# 34   0.102251  0.069174  1.478170  1.401200e-01                 .    CTSS
# 115 -0.414737  0.080152 -5.174400  3.563980e-07                 .   ERAP1
# 121 -0.339840  0.097212 -3.495840  5.233970e-04                 .   ERAP1
# ..        ...       ...       ...           ...               ...     ...
# 136       NaN       NaN       NaN           NaN  CONST_ALLELE,REF   ERAP2
# 156       NaN       NaN       NaN           NaN  CONST_ALLELE,REF   ERAP2
# 280 -1.523610  0.962937 -1.582260  1.169150e-01                 .   LAIR1
# 314  0.013029  0.133533  0.097571  9.224790e-01                 .  MARCH1
# 350       NaN       NaN       NaN           NaN  CONST_ALLELE,REF   DCTN5
#
#                                combo    z_score bootstrap p
# 32   Brain_Cerebellar_Hemisphere.LGG   5.584259    0.004191
# 33   Brain_Cerebellar_Hemisphere.LGG   5.384196    0.004185
# 34   Brain_Cerebellar_Hemisphere.LGG   5.384196    0.004448
# 115  Brain_Cerebellar_Hemisphere.LGG  10.471535    0.000000
# 121  Brain_Cerebellar_Hemisphere.LGG   4.980887    0.006497
# ..                               ...        ...         ...
# 136                      Testis.TGCT        NaN    0.000000
# 156                      Testis.TGCT        NaN    0.000000
# 280                      Testis.TGCT  13.086401    0.008327
# 314                      Testis.TGCT  14.041245    0.008415
# 350                      Testis.TGCT        NaN    0.000000
#
# [374 rows x 54 columns]

# %%
consensus_deviant=pd.DataFrame()

for x in brian_match_deviant["combo"].unique():
    df=brian_match_deviant[brian_match_deviant["combo"]==x]
    
    fire=firebrowse_match_deviant[firebrowse_match_deviant["combo"]==x]["assoc"].tolist()
    pancan=pancanatlas_match_deviant[pancanatlas_match_deviant["combo"]==x]["assoc"].tolist()
    
    df["firebrowse_support"]=np.where(df["assoc"].isin(fire),1,0)
    df["pancan_support"]=np.where(df["assoc"].isin(pancan),1,0)
    
    consensus_deviant=consensus_deviant.append(df)
# Out:
# /nrnb/opt/anaconda3.7/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /nrnb/opt/anaconda3.7/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
consensus_immune=pd.DataFrame()

for x in brian_immune_deviant["combo"].unique():
    df=brian_immune_deviant[brian_immune_deviant["combo"]==x]
    
    fire=firebrowse_immune_deviant[firebrowse_immune_deviant["combo"]==x]["assoc"].tolist()
    pancan=pancanatlas_immune_deviant[pancanatlas_immune_deviant["combo"]==x]["assoc"].tolist()
    
    df["firebrowse_support"]=np.where(df["assoc"].isin(fire),1,0)
    df["pancan_support"]=np.where(df["assoc"].isin(pancan),1,0)
    
    consensus_immune=consensus_immune.append(df)
# Out:
# /nrnb/opt/anaconda3.7/lib/python3.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if __name__ == '__main__':
# /nrnb/opt/anaconda3.7/lib/python3.7/site-packages/ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
consensus_deviant["sum"]=consensus_deviant["firebrowse_support"]+consensus_deviant["pancan_support"]
consensus_immune["sum"]=consensus_immune["firebrowse_support"]+consensus_immune["pancan_support"]

# %%
consensus_deviant=consensus_deviant[(consensus_deviant["sum"]>0)]
consensus_deviant=consensus_deviant[~(consensus_deviant["z_score"].isnull())]

# %%
consensus_immune=consensus_immune[(consensus_immune["sum"]>0)]
consensus_immune=consensus_immune[~(consensus_immune["z_score"].isnull())]

# %%
consensus_immune
# Out:
#      Unnamed: 0  Unnamed: 0.1          gene_id  gtex slope  gtex slope_se ref  \
# 189         189        312283  ENSG00000090382   -0.733674       0.017838   T
# 197         197        324043  ENSG00000132965    0.201135       0.016874   A
# 314         314        498253  ENSG00000172543   -0.321170       0.016645   A
# 315         315        499723  ENSG00000172543   -0.322041       0.016673   C
# 317         317        502663  ENSG00000171860   -0.757753       0.020938   A
# ..          ...           ...              ...         ...            ...  ..
# 232         232        375041  ENSG00000105501   -0.233404       0.030640   G
# 235         235        379391  ENSG00000171051   -0.000051       0.014088   A
# 317         317        502661  ENSG00000171860   -0.757753       0.020938   A
# 318         318        504131  ENSG00000171860   -0.756348       0.021118   A
# 328         328        518771  ENSG00000171051   -0.122421       0.012608   A
#
#     alt gtex cell_type           pval  gtex maf  ...    T_STAT             P  \
# 189   C    Whole_Blood  1.043525e-160  0.490143  ... -2.832170  5.237760e-03
# 197   T    Whole_Blood   6.299968e-29  0.254480  ... -0.804018  4.226180e-01
# 314   G    Whole_Blood   4.548993e-62  0.195341  ... -5.636230  7.999690e-08
# 315   A    Whole_Blood   3.647897e-62  0.194444  ... -5.636230  7.999690e-08
# 317   G    Whole_Blood  2.799990e-140  0.314516  ... -0.836885  4.039460e-01
# ..   ..            ...            ...       ...  ...       ...           ...
# 232   C    Whole_Blood   1.352654e-13  0.180108  ...  5.603190  7.309590e-08
# 235   C    Whole_Blood   9.971125e-01  0.312724  ...  1.901880  5.869930e-02
# 317   G    Whole_Blood  2.799990e-140  0.314516  ...  0.412456  6.804700e-01
# 318   G    Whole_Blood  1.125281e-138  0.313620  ...  0.368962  7.125670e-01
# 328   G    Whole_Blood   1.695486e-20  0.341398  ... -3.307100  1.127270e-03
#
#     ERRCODE    pheno             combo    z_score bootstrap p  \
# 189       .      LYZ  Whole_Blood.LIHC  23.898710    0.000000
# 197       .  ALOX5AP  Whole_Blood.LIHC  17.698141    0.009504
# 314       .     CTSW  Whole_Blood.LIHC  19.932937    0.009831
# 315       .     CTSW  Whole_Blood.LIHC  19.847493    0.009920
# 317       .    C3AR1  Whole_Blood.LIHC  31.697022    0.000000
# ..      ...      ...               ...        ...         ...
# 232       .  SIGLEC5  Whole_Blood.KIRP  28.975503    0.002516
# 235       .     FPR1  Whole_Blood.KIRP  14.998376    0.009861
# 317       .    C3AR1  Whole_Blood.KIRP  38.396332    0.000000
# 318       .    C3AR1  Whole_Blood.KIRP  37.796634    0.000000
# 328       .     FPR1  Whole_Blood.KIRP  17.579973    0.007356
#
#      firebrowse_support pancan_support sum
# 189                   1              1   2
# 197                   1              1   2
# 314                   1              1   2
# 315                   1              1   2
# 317                   1              1   2
# ..                  ...            ...  ..
# 232                   1              1   2
# 235                   1              1   2
# 317                   1              1   2
# 318                   1              1   2
# 328                   1              1   2
#
# [167 rows x 57 columns]

# %% [markdown]
# ## Keep only combos with least deviants

# %%
select=consensus_deviant["combo"].value_counts().reset_index()

# %%
select["cancer"]=select["index"].str.split(".").str[-1]
select["gtex"]=select["index"].str.split(".").str[0]

# %%
combos=[]

for x in select["cancer"].unique():
    df=select[select["cancer"]==x]
    combos.append(df[df["combo"]==df["combo"].min()]["index"].values[0])

# %% [markdown]
# ## Get brian comparison

# %%
compare_beta=pd.merge(snps_gtex_cis,tpm_cancer,on="assoc")
compare_beta["combo"]=compare_beta["gtex cell_type"]+"."+compare_beta["file_name"]
compare_beta["z_score"]=(compare_beta["gtex slope"]-compare_beta["BETA"])/compare_beta["gtex slope_se"]

# %%
compare_beta.head()
# Out:
#            gene_id  gtex slope  gtex slope_se ref alt gtex cell_type  \
# 0  ENSG00000049245    0.230936        0.10345   G   A  Kidney_Cortex
# 1  ENSG00000049245    0.230936        0.10345   G   A  Kidney_Cortex
# 2  ENSG00000049245    0.230936        0.10345   G   A  Kidney_Cortex
# 3  ENSG00000049245    0.230936        0.10345   G   A  Kidney_Cortex
# 4  ENSG00000049245    0.230936        0.10345   G   A  Kidney_Cortex
#
#        pval  gtex maf  tss_distance         variant id  ... TEST OBS_CT  \
# 0  0.030614  0.176923         10001  1_7841330_G_A_b37  ...  ADD     70
# 1  0.030614  0.176923         10001  1_7841330_G_A_b37  ...  ADD    322
# 2  0.030614  0.176923         10001  1_7841330_G_A_b37  ...  ADD    788
# 3  0.030614  0.176923         10001  1_7841330_G_A_b37  ...  ADD    176
# 4  0.030614  0.176923         10001  1_7841330_G_A_b37  ...  ADD     30
#
#        BETA        SE    T_STAT         P ERRCODE  pheno               combo  \
# 0  0.168077  0.276697  0.607441  0.546014       .  VAMP3   Kidney_Cortex.ACC
# 1  0.225966  0.123493  1.829790  0.068248       .  VAMP3  Kidney_Cortex.BLCA
# 2  0.136816  0.074679  1.832070  0.067325       .  VAMP3  Kidney_Cortex.BRCA
# 3  0.188130  0.180666  1.041310  0.299274       .  VAMP3  Kidney_Cortex.CESC
# 4  0.075788  0.441491  0.171664  0.865854       .  VAMP3  Kidney_Cortex.CHOL
#
#     z_score
# 0  0.607627
# 1  0.048045
# 2  0.909811
# 3  0.413786
# 4  1.499736
#
# [5 rows x 51 columns]

# %%
compare_beta=compare_beta[compare_beta["combo"].isin(combos)]
compare_beta=compare_beta[compare_beta["assoc"].isin(snps["assoc"].tolist())]

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(111)

n=compare_beta["file_name"].unique()
color=iter(cm.rainbow(np.linspace(0,1,len(n))))

for x in n:
    c=next(color)
    canc_filt_dev=compare_beta[compare_beta["file_name"]==x]
    plt.scatter(canc_filt_dev["gtex slope"],canc_filt_dev["BETA"],color=c,marker=".",label=x)


ax.set_xlabel("gtex beta")
ax.plot([ax.get_xlim()[0],ax.get_xlim()[1]], [ax.get_xlim()[0],ax.get_xlim()[1]], ls="--", c="k")
ax.set_ylabel("tcga beta")
plt.legend()
fig.savefig('gtex.beta.pdf')

# %%
compare_beta
# Out:
#                 gene_id  gtex slope  gtex slope_se ref alt  \
# 10      ENSG00000049245    0.230936       0.103450   G   A
# 11      ENSG00000049245    0.230936       0.103450   G   A
# 43      ENSG00000049245    0.172823       0.084241   G   A
# 62      ENSG00000049245    0.106642       0.028678   G   A
# 200     ENSG00000049245    0.313503       0.047852   G   A
# ...                 ...         ...            ...  ..  ..
# 530216  ENSG00000160255   -0.128154       0.029175   T   C
# 530243  ENSG00000160255   -0.191338       0.047046   T   C
# 530258  ENSG00000160255   -0.185616       0.079188   T   C
# 530485  ENSG00000160255   -0.100479       0.051243   T   C
# 530508  ENSG00000160255   -0.138218       0.036817   T   C
#
#                          gtex cell_type          pval  gtex maf  tss_distance  \
# 10                        Kidney_Cortex  3.061431e-02  0.176923         10001
# 11                        Kidney_Cortex  3.061431e-02  0.176923         10001
# 43                                Liver  4.210626e-02  0.148876         10001
# 62                Breast_Mammary_Tissue  2.428957e-04  0.133739         10001
# 200                            Prostate  9.748448e-10  0.154696         10001
# ...                                 ...           ...       ...           ...
# 530216                          Thyroid  1.426423e-05  0.170124        -23805
# 530243  Skin_Not_Sun_Exposed_Suprapubic  5.851649e-05  0.179070        -23805
# 530258             Minor_Salivary_Gland  2.130567e-02  0.140351        -23805
# 530485                           Testis  5.117121e-02  0.172794        -23805
# 530508                         Pancreas  2.270420e-04  0.160494        -23805
#
#                  variant id  ... TEST OBS_CT      BETA        SE    T_STAT  \
# 10        1_7841330_G_A_b37  ...  ADD    418  0.182127  0.111590  1.632110
# 11        1_7841330_G_A_b37  ...  ADD    204  0.194364  0.156992  1.238050
# 43        1_7841330_G_A_b37  ...  ADD    169  0.169693  0.186139  0.911651
# 62        1_7841330_G_A_b37  ...  ADD    788  0.136816  0.074679  1.832070
# 200       1_7841330_G_A_b37  ...  ADD    401  0.369310  0.101037  3.655200
# ...                     ...  ...  ...    ...       ...       ...       ...
# 530216  21_46328099_T_C_b37  ...  ADD    360  0.168186  0.106476  1.579560
# 530243  21_46328099_T_C_b37  ...  ADD     92  0.583658  0.213314  2.736150
# 530258  21_46328099_T_C_b37  ...  ADD    413  0.298984  0.090213  3.314190
# 530485  21_46328099_T_C_b37  ...  ADD    108  0.029083  0.190163  0.152937
# 530508  21_46328099_T_C_b37  ...  ADD    148  0.127147  0.165593  0.767827
#
#                P ERRCODE  pheno                                 combo  \
# 10      0.103436       .  VAMP3                    Kidney_Cortex.KIRC
# 11      0.217225       .  VAMP3                    Kidney_Cortex.KIRP
# 43      0.363368       .  VAMP3                            Liver.LIHC
# 62      0.067325       .  VAMP3            Breast_Mammary_Tissue.BRCA
# 200     0.000292       .  VAMP3                         Prostate.PRAD
# ...          ...     ...    ...                                   ...
# 530216  0.115121       .  ITGB2                          Thyroid.THCA
# 530243  0.007694       .  ITGB2  Skin_Not_Sun_Exposed_Suprapubic.SKCM
# 530258  0.001003       .  ITGB2             Minor_Salivary_Gland.HNSC
# 530485  0.878772       .  ITGB2                           Testis.TGCT
# 530508  0.443941       .  ITGB2                         Pancreas.PAAD
#
#           z_score
# 10       0.471814
# 11       0.353525
# 43       0.037160
# 62      -1.052165
# 200     -1.166240
# ...           ...
# 530216 -10.157206
# 530243 -16.473330
# 530258  -6.119597
# 530485  -2.528396
# 530508  -7.207687
#
# [7278 rows x 51 columns]

# %%
consensus_deviant.columns
# Out:
# Index(['Unnamed: 0', 'Unnamed: 0.1', 'gene_id', 'gtex slope', 'gtex slope_se',
#        'ref', 'alt', 'gtex cell_type', 'pval', 'gtex maf', 'tss_distance',
#        'variant id', 'variable', 'snps', 'gtex file', 'file', 'category',
#        'maf', 'variant', 'rsid', 'chr', 'brian beta', 'brian SE', 'brian P',
#        'REF_x', 'ALT_x', 'firebrowse beta', 'firebrowse SE', 'firebrowse P',
#        'pancan beta', 'pancan SE', 'pancan P', 'consensus p', 'p-value',
#        'cis tss', 'assoc', 'number', 'file_name', 'POS', 'ID', 'REF_y',
#        'ALT_y', 'A1', 'TEST', 'OBS_CT', 'BETA', 'SE', 'T_STAT', 'P', 'ERRCODE',
#        'pheno', 'combo', 'z_score', 'bootstrap p', 'firebrowse_support',
#        'pancan_support', 'sum'],
#       dtype='object')

# %%
consensus_deviant["file_name"]
# Out:
# 27     KIRP
# 83     KIRP
# 213    KIRP
# 27     BRCA
# 50     BRCA
#        ...
# 313    UCEC
# 314    UCEC
# 101     LGG
# 178     LGG
# 334     LGG
# Name: file_name, Length: 147, dtype: object

# %%
consensus_immune["file_name"]
# Out:
# 189    LIHC
# 197    LIHC
# 314    LIHC
# 315    LIHC
# 317    LIHC
#        ...
# 232    KIRP
# 235    KIRP
# 317    KIRP
# 318    KIRP
# 328    KIRP
# Name: file_name, Length: 167, dtype: object

# %%
compare_beta.columns
# Out:
# Index(['gene_id', 'gtex slope', 'gtex slope_se', 'ref', 'alt',
#        'gtex cell_type', 'pval', 'gtex maf', 'tss_distance', 'variant id',
#        'variable', 'snps', 'gtex file', 'file', 'category', 'maf', 'variant',
#        'rsid', 'chr', 'brian beta', 'brian SE', 'brian P', 'REF_x', 'ALT_x',
#        'firebrowse beta', 'firebrowse SE', 'firebrowse P', 'pancan beta',
#        'pancan SE', 'pancan P', 'consensus p', 'p-value', 'cis tss', 'assoc',
#        'number', 'file_name', 'POS', 'ID', 'REF_y', 'ALT_y', 'A1', 'TEST',
#        'OBS_CT', 'BETA', 'SE', 'T_STAT', 'P', 'ERRCODE', 'pheno', 'combo',
#        'z_score'],
#       dtype='object')

# %%
compare_beta["file_name"]
# Out:
# 10        KIRC
# 11        KIRP
# 43        LIHC
# 62        BRCA
# 200       PRAD
#           ...
# 530216    THCA
# 530243    SKCM
# 530258    HNSC
# 530485    TGCT
# 530508    PAAD
# Name: file_name, Length: 7278, dtype: object

# %%
compare_beta_annot=pd.DataFrame()

for x in compare_beta["file_name"].unique():
    print(x)
    
    df=compare_beta[compare_beta["file_name"]==x]
    
    deviant=consensus_deviant[consensus_deviant["file_name"]==x]["assoc"].tolist()
    immune=consensus_immune[consensus_immune["file_name"]==x]["assoc"].tolist()
    print(len(immune))
    df["deviant"]=np.where(df["assoc"].isin(deviant),"deviant","not deviant")
    df["immune"]=np.where(df["assoc"].isin(immune),"deviant","not deviant")
    
    compare_beta_annot=compare_beta_annot.append(df)
# Out:
# KIRC
# 5
# KIRP
# 10
# LIHC
# 6
# BRCA
# 16
# PRAD
# 12
# LGG
# 6
# COAD
# 9
# LUAD
# 24
# LUSC
# 9
# /nrnb/opt/anaconda3.7/lib/python3.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   # This is added back by InteractiveShellApp.init_path()
# /nrnb/opt/anaconda3.7/lib/python3.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   if sys.path[0] == '':
# UCEC
# 5
# STAD
# 6
# OV
# 7
# ESCA
# 1
# GBM
# 4
# ACC
# 3
# THCA
# 13
# SKCM
# 7
# HNSC
# 12
# TGCT
# 3
# PAAD
# 5

# %%
compare_beta_annot.head()
# Out:
#               gene_id  gtex slope  gtex slope_se ref alt gtex cell_type  \
# 10    ENSG00000049245    0.230936       0.103450   G   A  Kidney_Cortex
# 1480  ENSG00000049245   -0.019597       0.081479   G   A  Kidney_Cortex
# 2950  ENSG00000049245   -0.148097       0.113199   G   A  Kidney_Cortex
# 4420  ENSG00000137959   -0.006413       0.169628   A   T  Kidney_Cortex
# 5890  ENSG00000137944   -0.031803       0.106281   A   C  Kidney_Cortex
#
#           pval  gtex maf  tss_distance          variant id  ...      BETA  \
# 10    0.030614  0.176923         10001   1_7841330_G_A_b37  ...  0.182127
# 1480  0.811024  0.423077        137685   1_7969014_G_A_b37  ...  0.107017
# 2950  0.197416  0.146154        151487   1_7982816_G_A_b37  ... -0.216385
# 4420  0.970011  0.330769         15155  1_79100762_A_T_b37  ... -0.155153
# 5890  0.766136  0.338462       -828402  1_88625636_A_C_b37  ...  0.031394
#
#             SE    T_STAT         P ERRCODE   pheno               combo  \
# 10    0.111590  1.632110  0.103436       .   VAMP3  Kidney_Cortex.KIRC
# 1480  0.074486  1.436750  0.151564       .   VAMP3  Kidney_Cortex.KIRC
# 2950  0.098083 -2.206160  0.027935       .   VAMP3  Kidney_Cortex.KIRC
# 4420  0.075917 -2.043720  0.041629       .  IFI44L  Kidney_Cortex.KIRC
# 5890  0.071461  0.439318  0.660666       .   CCBL2  Kidney_Cortex.KIRC
#
#        z_score      deviant       immune
# 10    0.471814  not deviant  not deviant
# 1480 -1.553944  not deviant  not deviant
# 2950  0.603257  not deviant  not deviant
# 4420  0.876860  not deviant  not deviant
# 5890 -0.594625  not deviant  not deviant
#
# [5 rows x 53 columns]

# %%
compare_beta_annot[compare_beta_annot["deviant"]=="deviant"]["immune"].value_counts()
# Out:
# not deviant    87
# deviant        22
# Name: immune, dtype: int64

# %%
plt.figure(figsize=(10,5)) 
ax = sns.swarmplot(x="combo", y="z_score",hue="deviant",data=compare_beta_annot)
plt.xticks(rotation=90)
plt.savefig("gtex.swarmplot.pdf")

# %%
order=[item.get_text() for item in ax.get_xticklabels()]

# %%
deviant_counts=compare_beta_annot.groupby(["combo","deviant"]).size().reset_index()

# %%
deviant_counts=deviant_counts[deviant_counts["deviant"]=="deviant"]

# %%
compare_beta_annot["cancer"]=compare_beta_annot["combo"].str.split(".").str[1]

# %%
nml_cancer=pd.read_csv("/cellar/users/mpagadal/Data/projects/germline-immune/snp-tables/tcga-normal-cancer-type-beta-se.tsv",delimiter="\t")

# %%
nml_cancer=nml_cancer.rename(columns={"file_name":"cancer"})

# %%
compare_beta_annot=pd.merge(compare_beta_annot,nml_cancer[["cancer","assoc","BETA","SE"]],on=["cancer","assoc"],how="left")

# %%
compare_beta_annot["nml z"]=(compare_beta_annot["BETA_y"]-compare_beta_annot["gtex slope"])/compare_beta_annot["gtex slope_se"]

# %%
compare_beta_annot["normal support"]=np.where(abs(compare_beta_annot["nml z"])<abs(compare_beta_annot["z_score"]),"normal","other")

# %%
deviant_counts=compare_beta_annot.groupby(["combo","deviant","normal support"]).size().reset_index()

# %%
deviant_counts=deviant_counts[deviant_counts["deviant"]=="deviant"]

# %%
index=[]
nml_support=[]
no_support=[]

for x in order:
    index.append(x)
    try:
        num=deviant_counts[(deviant_counts["combo"]==x)&(deviant_counts["normal support"]=="other")][0].values[0] 
        no_support.append(num)
    except:
        no_support.append(0)
    
    try:
        num=deviant_counts[(deviant_counts["combo"]==x)&(deviant_counts["normal support"]=="normal")][0].values[0]
        nml_support.append(num)
    except:
        nml_support.append(0)
# Out:
# 1
# 1
# 2
# 29
# 2
# 4
# 1
# 2
# 2
# 5
# 3
# 6
# 3
# 1
# 4
# 2
# 3
# 3

# %%
nml_cancer["cancer"].unique()
# Out:
# array(['BLCA', 'BRCA', 'COAD', 'HNSC', 'KIRC', 'KIRP', 'LIHC', 'LUAD',
#        'LUSC', 'PRAD', 'STAD', 'THCA', 'UCEC'], dtype=object)

# %%
order
# Out:
# ['Kidney_Cortex.KIRC',
#  'Kidney_Cortex.KIRP',
#  'Liver.LIHC',
#  'Breast_Mammary_Tissue.BRCA',
#  'Prostate.PRAD',
#  'Brain_Substantia_nigra.LGG',
#  'Colon_Transverse.COAD',
#  'Lung.LUAD',
#  'Lung.LUSC',
#  'Uterus.UCEC',
#  'Stomach.STAD',
#  'Ovary.OV',
#  'Esophagus_Muscularis.ESCA',
#  'Brain_Anterior_cingulate_cortex_BA24.GBM',
#  'Adrenal_Gland.ACC',
#  'Thyroid.THCA',
#  'Skin_Not_Sun_Exposed_Suprapubic.SKCM',
#  'Minor_Salivary_Gland.HNSC',
#  'Testis.TGCT',
#  'Pancreas.PAAD']

# %%
plt.figure(figsize=(10,2)) 
p1 = plt.bar(index, nml_support,label="normal support")
p2 = plt.bar(index, no_support, bottom=nml_support,label="no support")
plt.legend()
plt.savefig("gtex.bar.swarmplot.pdf")

# %% [markdown]
# ## Plot Venn diagram of deviant snps

# %%
deviant_lst=compare_beta_annot[compare_beta_annot["deviant"]=="deviant"]
nml_lst=compare_beta_annot[(compare_beta_annot["deviant"]=="deviant")&(compare_beta_annot["normal support"]=="normal")]
immune_lst=compare_beta_annot[(compare_beta_annot["deviant"]=="deviant")&(compare_beta_annot["immune"]=="not deviant")]

# %%
venn3([set(deviant_lst["assoc"].tolist()),set(nml_lst["assoc"].tolist()),set(immune_lst["assoc"].tolist())],
      set_labels=("deviant","normal support","gtex whole blood"), set_colors=["blue","purple","green"])
plt.savefig("gtex.deviant.pie.pdf")
# Out:
# /cellar/users/mpagadal/.local/lib/python3.7/site-packages/matplotlib_venn/_venn3.py:117: UserWarning: Bad circle positioning
#   warnings.warn("Bad circle positioning")

# %% [markdown]
# ## Get beta plot
